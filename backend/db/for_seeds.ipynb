# %%
import pandas as pd

df = pd.read_csv('data-team-duckies.csv')

# %%
df
# Out:
#        sp_id    pid                                            content  \
# 0         59     21  Meet the bra that’s like a warm hug. From the ...
# 1        127     31  FRESH AT ToTT!  We've made space in our store ...
# 2       3117     49  'Good Buy' 2020, we are going to end you on a ...
# 3       3131     52  No such thing as "too many Air Force 1s" 👀 Cop...
# 4       3591     71  Science Aqua , it is not rebonding and not you...
# ...      ...    ...                                                ...
# 9995  230265  43393  Enjoy some quality ‘me time’ in the hustle and...
# 9996  233325  43440  Enjoy 𝗠𝗘𝗚𝗔 𝗦𝗔𝗩𝗜𝗡𝗚𝗦 and 𝐁𝐔𝐍𝐃𝐋𝐄 𝐃𝐄𝐀𝐋𝐒 at Pet Mas...
# 9997  233135  43441  Welcome November with the King of Crabs, the A...
# 9998  232638  43450  Eating for one is never boring at Burger King!...
# 9999  231729  43452  Yeah, they’re biscuits but HEAR US OUT. The Ba...
#
#                                               gen_title  \
# 0                            New Lavie Aisee Series Bra
# ...

# %%
df.to_dict()
# Out:
# {'sp_id': {0: 59,
#   1: 127,
#   2: 3117,
#   3: 3131,
#   4: 3591,
#   5: 3533,
#   6: 3318,
#   7: 3455,
#   8: 3449,
#   9: 3013,
#   10: 3101,
#   11: 4578,
#   12: 5539,
#   13: 3802,
#   14: 4306,
#   15: 7785,
#   16: 10217,
#   17: 9908,
#   18: 9849,
#   19: 8245,
#   20: 12208,
#   21: 12235,
#   22: 12040,
#   23: 13609,
#   24: 12222,
#   25: 14691,
#   26: 14901,
#   27: 15052,
#   28: 15951,
#   29: 16461,
#   30: 15493,
#   31: 16225,
#   32: 3509,
#   33: 12887,
#   34: 12675,
#   35: 15965,
#   36: 239,
#   37: 9967,
#   38: 12108,
#   39: 21451,
#   40: 16342,
#   41: 15529,
#   42: 16088,
#   43: 21655,
#   44: 21320,
#   45: 22993,
#   46: 23142,
#   47: 23140,
#   48: 20990,
#   49: 17009,
#   50: 22970,
#   51: 25508,
#   52: 25802,
#   53: 25519,
#   54: 23072,
#   55: 23332,
#   56: 21299,
#   57: 22988,
#   58: 25795,
#   59: 25757,
#   60: 21119,
#   61: 16277,
#   62: 23388,
#   63: 25864,
#   64: 25332,
#   65: 25327,
#   66: 25585,
#   67: 23641,
# ...

# %%
for i in range(len(df)):
    if df.iloc[i]['Team'] == 'Duckies':
        df.iloc[i]['Team'] = 'Duckies'
    else:
        df.iloc[i]['Team'] = 'Duckies'
